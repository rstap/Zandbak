# %%
# %pip install rdflib
# Out:
# Requirement already satisfied: rdflib in c:\users\roels\appdata\local\programs\python\python312\lib\site-packages (7.0.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in c:\users\roels\appdata\local\programs\python\python312\lib\site-packages (from rdflib) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\roels\appdata\local\programs\python\python312\lib\site-packages (from rdflib) (3.1.4)
# Requirement already satisfied: six in c:\users\roels\appdata\local\programs\python\python312\lib\site-packages (from isodate<0.7.0,>=0.6.0->rdflib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from rdflib import Graph, URIRef
from rdflib.namespace import RDFS, SKOS

# %%
g=Graph()
g.parse('https://www.wikidata.org/wiki/Special:EntityData/Q2831.ttl')
# Out:
# <Graph identifier=Ne1d230cd167b4d2594c1b540b53bd90b (<class 'rdflib.graph.Graph'>)>

# %%
len(g)
# Out:
# 26252

# %%
MJ = URIRef('http://www.wikidata.org/entity/Q2831')
for label in g.objects(MJ, SKOS.altLabel):
    print(label.value, label.language)
# Out:
# Michael Jackson ady
# The King of Pop ady
# MJ ady
# The King ady
# King of Pop ady
# King of Music ady
# ማይክል ጆሴፍ ጃክሰን am
# ملك البوب ar
# مايكل جوزيف جاكسون ar
# Michael Jackson arc
# The King of Pop arc
# MJ arc
# مايكل دجوزيف دجاكسون ary
# Michael Joe Jackson ast
# The King of Pop av
# MJ av
# Michael Jackson av
# Джексон, Майкл av
# Maykl Cozef Cekson az
# Michael Joe Jackson bar
# किंग ऑफ़ पॉप bho
# er ce
# ᎹᏱᎩᎵ ᏦᏎᏫ ᏤᎩᏌᏂ chr
# Michael Jackson crh
# Maykl Cozef Cekson crh
# Maikel Jakthon din
# Μάικλ Τζόζεφ Τζάκσον el
# Μάικλ Τζο Τζάκσον el
# Βασιλιάς της Ποπ el
# Miĥaelo Jozefo Jackson eo
# ام‌جی fa
# سلطان پاپ fa
# پادشاه پاپ fa
# ام.جی. fa
# مایکل جوزف جکسون fa
# 𐌼𐌹𐌺𐌰𐌴𐌻 𐌹𐌰𐌿𐍃𐌰𐌹𐍆 𐌳𐌹𐌰𐌹𐌺𐍃𐌰𐌿𐌽 got
# Michael Jackson iu
# MJ ja
# キング・オブ・ポップ ja
# Michael Jackson jbo
# Michael Joe Jackson jv
# ಮೈಕಲ್ ಜ್ಯಾಕ್ಸನ್ kn
# Michael Joe Jackson ku
# Michaël Iosephus Jackson la
# Michaël Jackson la
# Michael Iosephus Jackson la
# Michael Jackson lad
# Майкл Жозеф Жексон lez
# Maikls Džeksons ltg
# Michael Jackson lv
# Майкл Джозеф Джексон mhr
# Майкл Джексон mhr
# Майкл Джо Джексон mhr
# Джексон, Майкл Джозеф mhr
# പോപ് രാജാവ് ml
# കിംങ്ങ് ഓഫ് പോപ് ml
# എം.ജെ ml
# മൈക്കൽ ജോ ജാക്സൺ ml
# Майкл Жозеф Жэксон mn
# Michael Joe Jackson mt
# The King of Pop ab
# King of Pop ban
# The King of Pop ban
# MJ ban
# M.J. ban
# Michael Joe Jackson pt
# MJ pt
# Rei do Pop pt
# MJ da
# M.J. da
# M. J. da
# Michael Joe Jackson da
# The King of Pop da
# King of Pop da
# MJ ig
# The King of Pop ig
# The King ig
# King of Pop ig
# King of Music ig
# Eze Pop ig
# Rei do Pop pt-br
# Michael Joe Jackson pt-br
# MJ pt-br
# MJ fo
# MJ id
# The King of Pop id
# Michael Joe Jackson id
# M.J. id
# M. J. id
# King of Pop id
# King of Music id
# The King id
# The King of Pop avk
# King of Pop avk
# King of Music avk
# The King avk
# MJ avk
# MJ yo
# The King of Pop yo
# The King yo
# The King of Music yo
# King of Pop yo
# Ọba Pop yo
# The King of Pop bm
# MJ bm
# The King bm
# King of Pop bm
# King of Music bm
# M.J. bm
# The King of Pop gur
# MJ gur
# King of Music gur
# Michael Joe Jackson sco
# Keeng o Pop sco
# Michael Joe Jackson dsb
# MJ sl
# Kralj popa sl
# Michael Joe Jackson sl
# John Jay Smith sl
# M. J. kg
# John Jay Smith kg
# King of Pop kg
# MJ dag
# MJ bug
# John Jay Smith bug
# M.J. kcg
# M. J. kcg
# The King of Pop kcg
# King of Pop kcg
# MJ zea
# MJ bi
# Maykl Djekson gag
# Maykl Djozef Djekson gag
# Michael Joe Jackson rmy
# MJ rmy
# M. J. rmy
# Michael Joe Jackson hak
# MJ hak
# M. J. hak
# John Jay Smith hak
# MJ pap
# Michael Joe Jackson pap
# Michael Joseph Jackson ace
# MJ ace

# %%
# DEZE IS NIET WERKEND OMDAT Graph.preferredLabel in nieuwe libarary is verwijderd
# labels = g.preferredLabel(MJ, labelProperties=(SKOS.altLabel))
# for prop, label in labels:
#     print(label.value, label.language)

# %%
qres = g.query("""
    SELECT ?label
    WHERE {
        wd:Q2831 skos:altLabel ?label .
    }
""")

for label, *_ in qres:
    print(label.value, label.language)

# %%
qres = g.query(""" 
    SELECT DISTINCT ?label
    WHERE {
        wd:Q2831 rdfs:label | skos:altLabel |skos:altLabel ?label .
        FILTER (lang(?label) = 'en')
    }
    ORDER BY ?label
""")

for label, *_ in qres:
    print(label)

# %%
qres = g.query(""" 
    SELECT  ?label ?discription
    WHERE {
        wd:Q2831 wdt:P166 ?award . 
        # ?award rdfs:label ?label .
        FILTER (lang(?label) = 'en')
        OPTIONAL{
            # ?award schema:description ?description
            FILTER (lang(?description) = 'en')
        }
    }
""")
for label, description in qres:
    print(f'Award: {label:<55} Description: {description}')

# %%
# %timeit -n 1000 list(g.objects(MJ, RDFS.label))

# %%
# %timeit -n 1000 g.query('SELECT ?label WHERE {wd:Q2831 rdfs:label ?label}')
